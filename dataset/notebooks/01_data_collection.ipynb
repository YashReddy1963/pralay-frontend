# %% [markdown]
# # OceanWatch Sentinel - Data Collection
#
# This notebook demonstrates how to collect and organize ocean hazard images for AI training.
#
# Based on the [TinyCamML Flood-Model](https://github.com/TinyCamML/Flood-Model.git) approach.

# %%
import sys
import os
sys.path.append('../src')

from data_collection import OceanHazardDataCollector
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
